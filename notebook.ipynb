# %%
import json
import sqlite3
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine

DATABASE_NAME = 'database.db'
TABLE_NAME = 'BAKERIES'

engine = create_engine(f'sqlite:///{DATABASE_NAME}', echo=False)

# Initialize the database
def init_db():
    conn = sqlite3.connect(DATABASE_NAME)
    cursor = conn.cursor()
    cursor.execute(f'''
        CREATE TABLE IF NOT EXISTS {TABLE_NAME} (
            ID INTEGER PRIMARY KEY AUTOINCREMENT,
            FirstName TEXT NOT NULL,
            LastName TEXT NOT NULL,
            NID TEXT NOT NULL,
            City TEXT NOT NULL,
            Region TEXT NOT NULL,
            District TEXT NOT NULL,
            Lat REAL NOT NULL,
            Lon REAL NOT NULL,
            HouseholdRisk TEXT NOT NULL,
            BakersRisk TEXT NOT NULL,
            TypeFlour INTEGER NOT NULL,
            TypeBread TEXT NOT NULL,
            BreadRations INTEGER NOT NULL
        )
    ''')
    conn.commit()
    conn.close()

init_db()

df = pd.read_csv("./assets/data/data.csv")
gdf_regions = gpd.read_file('./assets/data/geodatabase/Region.geojson')
gdf_district = gpd.read_file('./assets/data/geodatabase/District.geojson')

# FirstName, LastName, NID, City, Lat, Lon, HouseholdRisk, BakersRisk, TypeFlour, TypeBread, BreadRations
COLs = ['FirstName', 'LastName', 'City', 'HouseholdRisk', 'BakersRisk', 'TypeBread']
df[COLs] = df[COLs].astype(str)
df[COLs] = df[COLs].apply(lambda x: x.str.rstrip())
df[COLs] = df[COLs].apply(lambda x: x.str.lstrip())
df[COLs] = df[COLs].apply(lambda x: x.str.replace(' +', ' '))
df[COLs] = df[COLs].apply(lambda x: x.str.replace('ي','ی'))
df[COLs] = df[COLs].apply(lambda x: x.str.replace('ئ','ی'))
df[COLs] = df[COLs].apply(lambda x: x.str.replace('ك', 'ک'))

COLs = ['NID', 'TypeFlour', 'BreadRations']
df[COLs] = df[COLs].astype(int)

COLs = ['Lat', 'Lon']
df[COLs] = df[COLs].astype(float)

# Drop All NULL Value from Lat & Lon Columns
df.dropna(subset=['Lat', 'Lon'], inplace=True)

# # Remove Duplicate NID
# df.drop_duplicates(subset=['NID'], inplace=True)

# # Remove Same Lat & Lon
# df.drop_duplicates(subset=['Lat', 'Lon'], inplace=True)

# Convert NID to `str`
df['NID'] = df['NID'].apply(lambda x: str(x).zfill(10))

# Reset Index
df.reset_index(drop=True, inplace=True)

gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['Lon'], df['Lat'])
)

gdf = gdf.set_crs('EPSG:4326')
gdf_regions = gdf_regions.to_crs('EPSG:4326')
gdf_district = gdf_district.to_crs('EPSG:4326')

gdf_joined_gdf_regions = gpd.sjoin(gdf, gdf_regions, how='left', op='within')
gdf_joined_gdf_district = gpd.sjoin(gdf, gdf_district, how='left', op='within')

df['Region'] = gdf_joined_gdf_regions['Region']
df['District'] = gdf_joined_gdf_district['District']

# Drop All NULL Value from Region & Lon District
df.dropna(subset=['Region', 'District'], inplace=True)

# Save to Database
df.to_sql(name='BAKERIES', con=engine, if_exists='append', index=False)
# Out:
# c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\default.py:938, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     937 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 938     cursor.executemany(statement, parameters)
#
# IntegrityError: NOT NULL constraint failed: BAKERIES.Region
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[1], line 93
#      87 df['District'] = gdf_joined_gdf_district['District']
#      89 # Drop All NULL Value from Region & Lon District
#      90 # df.dropna(subset=['Region', 'District'], inplace=True)
#      91
#      92 # Save to Database
# ---> 93 df.to_sql(name='BAKERIES', con=engine, if_exists='append', index=False)
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\pandas\io\sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\pandas\io\sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\pandas\io\sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\pandas\io\sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1934                 break
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#    1943     if self.dialect._has_events:
#
# File c:\Users\psh2610\AppData\Local\miniconda3\Lib\site-packages\sqlalchemy\engine\default.py:938, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     937 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 938     cursor.executemany(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) NOT NULL constraint failed: BAKERIES.Region
# [SQL: INSERT INTO "BAKERIES" ("FirstName", "LastName", "NID", "City", "Lat", "Lon", "HouseholdRisk", "BakersRisk", "TypeFlour", "TypeBread", "BreadRations", "Region", "District") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: [('اشرف', 'زارع میرک آباد', '0452245567', 'مشهد', 35.06, 59.47, 'کم ریسک', 'پرریسک', 6, 'سنگک', 150, None, None), ('اشرف', 'زارع میرک آباد', '0452245567', 'مشهد', 35.08, 59.98, 'پرریسک', 'کم ریسک', 4, 'تافتون', 400, None, None), ('احمدرضا', 'وصالی کاخکی', '0452343089', 'مشهد', 35.19, 59.18, 'ریسک متوسط', 'کم ریسک', 4, 'تافتون', 100, None, None), ('احمدرضا', 'وصالی کاخکی', '0452343089', 'مشهد', 35.21, 58.15, 'پرریسک', 'کم ریسک', 2, 'تافتون', 350, None, None), ('کمال', 'انصاری شهری', '0453325556', 'مشهد', 35.27, 59.23, 'ریسک متوسط', 'ریسک متوسط', 4, 'لواش', 100, None, None), ('کمال', 'انصاری شهری', '0453325556', 'مشهد', 35.28, 59.22, 'خیلی پرریسک', 'پرریسک', 2, 'سنگک', 350, None, None), ('حسین', 'جمشیدزاده', '0490824315', 'مشهد', 35.32, 59.69, 'ریسک متوسط', 'خیلی پرریسک', 4, 'بربری', 100, None, None), ('حسین', 'جمشیدزاده', '0490824315', 'مشهد', 35.41, 59.66, 'کم ریسک', 'کم ریسک', 4, 'تافتون', 100, None, None)  ... displaying 10 of 2194 total bound parameter sets ...  ('محسن', 'نظامی', '0936774770', 'مشهد', 37.41, 59.93, 'خیلی پرریسک', 'پرریسک', 4, 'سنگک', 400, None, None), ('باقر', 'جعفرپورکوشک مهدی', '0936788062', 'مشهد', 37.48, 59.38, 'ریسک متوسط', 'خیلی پرریسک', 4, 'بربری', 100, None, None)]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
df.columns
# Out:
# Index(['FirstName', 'LastName', 'NID', 'City', 'Lat', 'Lon', 'HouseholdRisk',
#        'BakersRisk', 'TypeFlour', 'TypeBread', 'BreadRations', 'Region',
#        'District'],
#       dtype='object')

# %%
# tmp = df[[
#     'City', 'Region', 'District',
#     'HouseholdRisk', 'BakersRisk', 'TypeFlour', 'TypeBread', 'BreadRations'
# ]]

tmp = df[[
    'City', 'Region', 'District', 'TypeBread'
]]

def build_hierarchy(data, keys):
    if not keys:
        return {'size': len(data)}
    result = []
    for key, group in data.groupby(keys[0]):
        
        if key in list(data['TypeBread'].unique()):
            result.append({
                'name': key,
                'size': len(group['TypeBread'])
            })
        else:
            result.append({
                'name': key,
                'children': build_hierarchy(group, keys[1:]) if len(keys) > 1 else len(group['TypeBread'])
            })
            
    return result

# Build the hierarchical structure
# hierarchy = build_hierarchy(tmp, ['City', 'Region', 'District', 'HouseholdRisk', 'BakersRisk', 'TypeFlour', 'TypeBread', 'BreadRations'])
hierarchy = build_hierarchy(tmp, ['City', 'Region', 'District', 'TypeBread'])

# Convert to JSON
hierarchical_json = {'name': 'Root', 'children': hierarchy}

hierarchical_json
# Out:
# {'name': 'Root',
#  'children': [{'name': 'مشهد',
#    'children': [{'name': 'منطقه 1',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 4},
#         {'name': 'تافتون', 'size': 6},
#         {'name': 'سنگک', 'size': 5},
#         {'name': 'لواش', 'size': 4}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 9},
#         {'name': 'تافتون', 'size': 12},
#         {'name': 'سنگک', 'size': 9},
#         {'name': 'لواش', 'size': 11}]}]},
#     {'name': 'منطقه 10',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 8},
#         {'name': 'تافتون', 'size': 9},
#         {'name': 'سنگک', 'size': 9},
#         {'name': 'لواش', 'size': 5}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 15},
#         {'name': 'تافتون', 'size': 15},
#         {'name': 'سنگک', 'size': 18},
#         {'name': 'لواش', 'size': 13}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 24},
#         {'name': 'تافتون', 'size': 26},
#         {'name': 'سنگک', 'size': 20},
#         {'name': 'لواش', 'size': 23}]}]},
#     {'name': 'منطقه 11',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 8},
#         {'name': 'تافتون', 'size': 12},
#         {'name': 'سنگک', 'size': 9},
#         {'name': 'لواش', 'size': 8}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 7},
#         {'name': 'تافتون', 'size': 5},
#         {'name': 'سنگک', 'size': 5},
#         {'name': 'لواش', 'size': 10}]}]},
#     {'name': 'منطقه 12',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 8},
#         {'name': 'تافتون', 'size': 11},
#         {'name': 'سنگک', 'size': 6},
#         {'name': 'لواش', 'size': 7}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 3},
#         {'name': 'تافتون', 'size': 8},
#         {'name': 'سنگک', 'size': 9},
#         {'name': 'لواش', 'size': 5}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 9},
#         {'name': 'تافتون', 'size': 8},
#         {'name': 'سنگک', 'size': 11},
#         {'name': 'لواش', 'size': 11}]}]},
#     {'name': 'منطقه 13',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'تافتون', 'size': 1},
#         {'name': 'سنگک', 'size': 1},
#         {'name': 'لواش', 'size': 2}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 2},
#         {'name': 'تافتون', 'size': 1},
#         {'name': 'سنگک', 'size': 4},
#         {'name': 'لواش', 'size': 2}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 4},
#         {'name': 'تافتون', 'size': 4},
#         {'name': 'سنگک', 'size': 7},
#         {'name': 'لواش', 'size': 4}]},
#       {'name': 'ناحیه 4',
#        'children': [{'name': 'تافتون', 'size': 2},
#         {'name': 'سنگک', 'size': 2},
#         {'name': 'لواش', 'size': 4}]}]},
#     {'name': 'منطقه 2',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 37},
#         {'name': 'تافتون', 'size': 28},
#         {'name': 'سنگک', 'size': 23},
#         {'name': 'لواش', 'size': 27}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 4},
#         {'name': 'تافتون', 'size': 6},
#         {'name': 'سنگک', 'size': 4},
#         {'name': 'لواش', 'size': 9}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 17},
#         {'name': 'تافتون', 'size': 11},
#         {'name': 'سنگک', 'size': 18},
#         {'name': 'لواش', 'size': 25}]},
#       {'name': 'ناحیه 4',
#        'children': [{'name': 'بربری', 'size': 19},
#         {'name': 'تافتون', 'size': 12},
#         {'name': 'سنگک', 'size': 11},
#         {'name': 'لواش', 'size': 8}]}]},
#     {'name': 'منطقه 3',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 19},
#         {'name': 'تافتون', 'size': 15},
#         {'name': 'سنگک', 'size': 16},
#         {'name': 'لواش', 'size': 9}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 26},
#         {'name': 'تافتون', 'size': 33},
#         {'name': 'سنگک', 'size': 31},
#         {'name': 'لواش', 'size': 28}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 19},
#         {'name': 'تافتون', 'size': 27},
#         {'name': 'سنگک', 'size': 21},
#         {'name': 'لواش', 'size': 19}]},
#       {'name': 'ناحیه 4',
#        'children': [{'name': 'بربری', 'size': 10},
#         {'name': 'تافتون', 'size': 4},
#         {'name': 'سنگک', 'size': 4},
#         {'name': 'لواش', 'size': 9}]}]},
#     {'name': 'منطقه 4',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 10},
#         {'name': 'تافتون', 'size': 6},
#         {'name': 'سنگک', 'size': 9},
#         {'name': 'لواش', 'size': 8}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 1},
#         {'name': 'تافتون', 'size': 4},
#         {'name': 'سنگک', 'size': 2},
#         {'name': 'لواش', 'size': 6}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 23},
#         {'name': 'تافتون', 'size': 29},
#         {'name': 'سنگک', 'size': 34},
#         {'name': 'لواش', 'size': 34}]}]},
#     {'name': 'منطقه 5',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 12},
#         {'name': 'تافتون', 'size': 11},
#         {'name': 'سنگک', 'size': 5},
#         {'name': 'لواش', 'size': 11}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 18},
#         {'name': 'تافتون', 'size': 22},
#         {'name': 'سنگک', 'size': 17},
#         {'name': 'لواش', 'size': 25}]}]},
#     {'name': 'منطقه 6',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 13},
#         {'name': 'تافتون', 'size': 9},
#         {'name': 'سنگک', 'size': 14},
#         {'name': 'لواش', 'size': 11}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 16},
#         {'name': 'تافتون', 'size': 17},
#         {'name': 'سنگک', 'size': 6},
#         {'name': 'لواش', 'size': 10}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 15},
#         {'name': 'تافتون', 'size': 21},
#         {'name': 'سنگک', 'size': 12},
#         {'name': 'لواش', 'size': 20}]}]},
#     {'name': 'منطقه 7',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 13},
#         {'name': 'تافتون', 'size': 7},
#         {'name': 'سنگک', 'size': 9},
#         {'name': 'لواش', 'size': 12}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 12},
#         {'name': 'تافتون', 'size': 19},
#         {'name': 'سنگک', 'size': 18},
#         {'name': 'لواش', 'size': 19}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 6},
#         {'name': 'تافتون', 'size': 6},
#         {'name': 'سنگک', 'size': 7},
#         {'name': 'لواش', 'size': 3}]}]},
#     {'name': 'منطقه 8',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 3},
#         {'name': 'تافتون', 'size': 1},
#         {'name': 'سنگک', 'size': 4},
#         {'name': 'لواش', 'size': 1}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 5},
#         {'name': 'تافتون', 'size': 3},
#         {'name': 'سنگک', 'size': 1},
#         {'name': 'لواش', 'size': 4}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 8},
#         {'name': 'تافتون', 'size': 8},
#         {'name': 'سنگک', 'size': 8},
#         {'name': 'لواش', 'size': 6}]}]},
#     {'name': 'منطقه 9',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'size': 14},
#         {'name': 'تافتون', 'size': 12},
#         {'name': 'سنگک', 'size': 13},
#         {'name': 'لواش', 'size': 11}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'size': 5},
#         {'name': 'تافتون', 'size': 8},
#         {'name': 'سنگک', 'size': 8},
#         {'name': 'لواش', 'size': 7}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'size': 13},
#         {'name': 'تافتون', 'size': 11},
#         {'name': 'سنگک', 'size': 13},
#         {'name': 'لواش', 'size': 13}]}]}]}]}

# %%
with open('sunburst_data.json', 'w') as json_file:
    json.dump(hierarchical_json, json_file, indent=4)
