# %%
import json
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine

engine = create_engine('sqlite:///database.db', echo=False)

df = pd.read_csv("./assets/data/data.csv")
gdf_regions = gpd.read_file('./assets/data/geodatabase/Region.geojson')
gdf_district = gpd.read_file('./assets/data/geodatabase/District.geojson')

# FirstName, LastName, NID, City, Lat, Lon, HouseholdRisk, BakersRisk, TypeFlour, TypeBread, BreadRations
COLs = ['FirstName', 'LastName', 'City', 'HouseholdRisk', 'BakersRisk', 'TypeBread']
df[COLs] = df[COLs].astype(str)
df[COLs] = df[COLs].apply(lambda x: x.str.rstrip())
df[COLs] = df[COLs].apply(lambda x: x.str.lstrip())
df[COLs] = df[COLs].apply(lambda x: x.str.replace(' +', ' '))
df[COLs] = df[COLs].apply(lambda x: x.str.replace('ي','ی'))
df[COLs] = df[COLs].apply(lambda x: x.str.replace('ئ','ی'))
df[COLs] = df[COLs].apply(lambda x: x.str.replace('ك', 'ک'))

COLs = ['NID', 'TypeFlour', 'BreadRations']
df[COLs] = df[COLs].astype(int)

COLs = ['Lat', 'Lon']
df[COLs] = df[COLs].astype(float)

# Drop All NULL Value from Lat & Lon Columns
df.dropna(subset=['Lat', 'Lon'], inplace=True)

# # Remove Duplicate NID
# df.drop_duplicates(subset=['NID'], inplace=True)

# # Remove Same Lat & Lon
# df.drop_duplicates(subset=['Lat', 'Lon'], inplace=True)

# Convert NID to `str`
df['NID'] = df['NID'].apply(lambda x: str(x).zfill(10))

# Reset Index
df.reset_index(drop=True, inplace=True)

gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['Lon'], df['Lat'])
)

gdf = gdf.set_crs('EPSG:4326')
gdf_regions = gdf_regions.to_crs('EPSG:4326')
gdf_district = gdf_district.to_crs('EPSG:4326')

gdf_joined_gdf_regions = gpd.sjoin(gdf, gdf_regions, how='left', op='within')
gdf_joined_gdf_district = gpd.sjoin(gdf, gdf_district, how='left', op='within')

df['Region'] = gdf_joined_gdf_regions['Region']
df['District'] = gdf_joined_gdf_district['District']

# Save to Database
# df.to_sql(name='BAKERIES', con=engine, if_exists='replace', index=False)
# Out:
# c:\Users\Pooya\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# c:\Users\Pooya\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
df.columns
# Out:
# Index(['FirstName', 'LastName', 'NID', 'City', 'Lat', 'Lon', 'HouseholdRisk',
#        'BakersRisk', 'TypeFlour', 'TypeBread', 'BreadRations', 'Region',
#        'District'],
#       dtype='object')

# %%
# tmp = df[[
#     'City', 'Region', 'District',
#     'HouseholdRisk', 'BakersRisk', 'TypeFlour', 'TypeBread', 'BreadRations'
# ]]

tmp = df[[
    'City', 'Region', 'District', 'TypeBread'
]]

def build_hierarchy(data, keys):
    if not keys:
        return {'size': len(data)}
    result = []
    for key, group in data.groupby(keys[0]):
        result.append({
            'name': key,
            'children': build_hierarchy(group, keys[1:]) if len(keys) > 1 else len(group['TypeBread'])
        })
    return result

# Build the hierarchical structure
# hierarchy = build_hierarchy(tmp, ['City', 'Region', 'District', 'HouseholdRisk', 'BakersRisk', 'TypeFlour', 'TypeBread', 'BreadRations'])
hierarchy = build_hierarchy(tmp, ['City', 'Region', 'District', 'TypeBread'])

# Convert to JSON
hierarchical_json = {'name': 'Root', 'children': hierarchy}

hierarchical_json
# Out:
# {'name': 'Root',
#  'children': [{'name': 'مشهد',
#    'children': [{'name': 'منطقه 1',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 4},
#         {'name': 'تافتون', 'children': 6},
#         {'name': 'سنگک', 'children': 5},
#         {'name': 'لواش', 'children': 4}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 9},
#         {'name': 'تافتون', 'children': 12},
#         {'name': 'سنگک', 'children': 9},
#         {'name': 'لواش', 'children': 11}]}]},
#     {'name': 'منطقه 10',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 8},
#         {'name': 'تافتون', 'children': 9},
#         {'name': 'سنگک', 'children': 9},
#         {'name': 'لواش', 'children': 5}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 15},
#         {'name': 'تافتون', 'children': 15},
#         {'name': 'سنگک', 'children': 18},
#         {'name': 'لواش', 'children': 13}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 24},
#         {'name': 'تافتون', 'children': 26},
#         {'name': 'سنگک', 'children': 20},
#         {'name': 'لواش', 'children': 23}]}]},
#     {'name': 'منطقه 11',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 8},
#         {'name': 'تافتون', 'children': 12},
#         {'name': 'سنگک', 'children': 9},
#         {'name': 'لواش', 'children': 8}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 7},
#         {'name': 'تافتون', 'children': 5},
#         {'name': 'سنگک', 'children': 5},
#         {'name': 'لواش', 'children': 10}]}]},
#     {'name': 'منطقه 12',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 8},
#         {'name': 'تافتون', 'children': 11},
#         {'name': 'سنگک', 'children': 6},
#         {'name': 'لواش', 'children': 7}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 3},
#         {'name': 'تافتون', 'children': 8},
#         {'name': 'سنگک', 'children': 9},
#         {'name': 'لواش', 'children': 5}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 9},
#         {'name': 'تافتون', 'children': 8},
#         {'name': 'سنگک', 'children': 11},
#         {'name': 'لواش', 'children': 11}]}]},
#     {'name': 'منطقه 13',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'تافتون', 'children': 1},
#         {'name': 'سنگک', 'children': 1},
#         {'name': 'لواش', 'children': 2}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 2},
#         {'name': 'تافتون', 'children': 1},
#         {'name': 'سنگک', 'children': 4},
#         {'name': 'لواش', 'children': 2}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 4},
#         {'name': 'تافتون', 'children': 4},
#         {'name': 'سنگک', 'children': 7},
#         {'name': 'لواش', 'children': 4}]},
#       {'name': 'ناحیه 4',
#        'children': [{'name': 'تافتون', 'children': 2},
#         {'name': 'سنگک', 'children': 2},
#         {'name': 'لواش', 'children': 4}]}]},
#     {'name': 'منطقه 2',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 37},
#         {'name': 'تافتون', 'children': 28},
#         {'name': 'سنگک', 'children': 23},
#         {'name': 'لواش', 'children': 27}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 4},
#         {'name': 'تافتون', 'children': 6},
#         {'name': 'سنگک', 'children': 4},
#         {'name': 'لواش', 'children': 9}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 17},
#         {'name': 'تافتون', 'children': 11},
#         {'name': 'سنگک', 'children': 18},
#         {'name': 'لواش', 'children': 25}]},
#       {'name': 'ناحیه 4',
#        'children': [{'name': 'بربری', 'children': 19},
#         {'name': 'تافتون', 'children': 12},
#         {'name': 'سنگک', 'children': 11},
#         {'name': 'لواش', 'children': 8}]}]},
#     {'name': 'منطقه 3',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 19},
#         {'name': 'تافتون', 'children': 15},
#         {'name': 'سنگک', 'children': 16},
#         {'name': 'لواش', 'children': 9}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 26},
#         {'name': 'تافتون', 'children': 33},
#         {'name': 'سنگک', 'children': 31},
#         {'name': 'لواش', 'children': 28}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 19},
#         {'name': 'تافتون', 'children': 27},
#         {'name': 'سنگک', 'children': 21},
#         {'name': 'لواش', 'children': 19}]},
#       {'name': 'ناحیه 4',
#        'children': [{'name': 'بربری', 'children': 10},
#         {'name': 'تافتون', 'children': 4},
#         {'name': 'سنگک', 'children': 4},
#         {'name': 'لواش', 'children': 9}]}]},
#     {'name': 'منطقه 4',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 10},
#         {'name': 'تافتون', 'children': 6},
#         {'name': 'سنگک', 'children': 9},
#         {'name': 'لواش', 'children': 8}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 1},
#         {'name': 'تافتون', 'children': 4},
#         {'name': 'سنگک', 'children': 2},
#         {'name': 'لواش', 'children': 6}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 23},
#         {'name': 'تافتون', 'children': 29},
#         {'name': 'سنگک', 'children': 34},
#         {'name': 'لواش', 'children': 34}]}]},
#     {'name': 'منطقه 5',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 12},
#         {'name': 'تافتون', 'children': 11},
#         {'name': 'سنگک', 'children': 5},
#         {'name': 'لواش', 'children': 11}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 18},
#         {'name': 'تافتون', 'children': 22},
#         {'name': 'سنگک', 'children': 17},
#         {'name': 'لواش', 'children': 25}]}]},
#     {'name': 'منطقه 6',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 13},
#         {'name': 'تافتون', 'children': 9},
#         {'name': 'سنگک', 'children': 14},
#         {'name': 'لواش', 'children': 11}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 16},
#         {'name': 'تافتون', 'children': 17},
#         {'name': 'سنگک', 'children': 6},
#         {'name': 'لواش', 'children': 10}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 15},
#         {'name': 'تافتون', 'children': 21},
#         {'name': 'سنگک', 'children': 12},
#         {'name': 'لواش', 'children': 20}]}]},
#     {'name': 'منطقه 7',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 13},
#         {'name': 'تافتون', 'children': 7},
#         {'name': 'سنگک', 'children': 9},
#         {'name': 'لواش', 'children': 12}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 12},
#         {'name': 'تافتون', 'children': 19},
#         {'name': 'سنگک', 'children': 18},
#         {'name': 'لواش', 'children': 19}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 6},
#         {'name': 'تافتون', 'children': 6},
#         {'name': 'سنگک', 'children': 7},
#         {'name': 'لواش', 'children': 3}]}]},
#     {'name': 'منطقه 8',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 3},
#         {'name': 'تافتون', 'children': 1},
#         {'name': 'سنگک', 'children': 4},
#         {'name': 'لواش', 'children': 1}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 5},
#         {'name': 'تافتون', 'children': 3},
#         {'name': 'سنگک', 'children': 1},
#         {'name': 'لواش', 'children': 4}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 8},
#         {'name': 'تافتون', 'children': 8},
#         {'name': 'سنگک', 'children': 8},
#         {'name': 'لواش', 'children': 6}]}]},
#     {'name': 'منطقه 9',
#      'children': [{'name': 'ناحیه 1',
#        'children': [{'name': 'بربری', 'children': 14},
#         {'name': 'تافتون', 'children': 12},
#         {'name': 'سنگک', 'children': 13},
#         {'name': 'لواش', 'children': 11}]},
#       {'name': 'ناحیه 2',
#        'children': [{'name': 'بربری', 'children': 5},
#         {'name': 'تافتون', 'children': 8},
#         {'name': 'سنگک', 'children': 8},
#         {'name': 'لواش', 'children': 7}]},
#       {'name': 'ناحیه 3',
#        'children': [{'name': 'بربری', 'children': 13},
#         {'name': 'تافتون', 'children': 11},
#         {'name': 'سنگک', 'children': 13},
#         {'name': 'لواش', 'children': 13}]}]}]}]}

# %%
with open('sunburst_data.json', 'w') as json_file:
    json.dump(hierarchical_json, json_file, indent=4)
